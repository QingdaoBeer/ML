# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Colab Notebooks/Github
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github

# %%
# !git clone https://QingdaoBeer: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@github.com/QingdaoBeer/ML.git
# Out:
# Cloning into 'ML'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 3 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), 17.79 KiB | 2.96 MiB/s, done.

# %%
cd ML
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/ML

# %%
# !git config --global user.email 'qingdaocraftbeer@gmail.com'
# !git config --global user.name 'QingdaoBeer'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	02_01_shuffle.ipynb
# 	02_02_data preprocessing.ipynb
# 	03_01_knearest regression.ipynb
# 	03_02_linear reg.ipynb
# 	03_03_multi reg.ipynb
# 	04_01_logistic reg.ipynb
# 	04_02_sgd.ipynb
# 	05_01_decision tree.ipynb
# 	05_02_cross validation and grid search.ipynb
# 	05_03_trees.ipynb
# 	06_01_clustering.ipynb
# 	06_02_kmean.ipynb
# 	06_03_pca.ipynb
# 	07_01_NN.ipynb
# 	07_02_deep nn.ipynb
# 	07_03_training nn.ipynb
# 	Untitled0.ipynb
# 	Untitled1.ipynb
# 	test_repo (1).ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
