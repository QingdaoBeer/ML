# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(train_input.shape)
print(train_target.shape)
print(train_target[:5])
# Out:
# (60000, 28, 28)
# (60000,)
# [9 0 0 3 0]

# %%
from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0
print(train_scaled.shape)
train_scaled = train_scaled.reshape(-1, 28*28)
print(train_scaled.shape)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)
# Out:
# (60000, 28, 28)
# (60000, 784)

# %%
# 1. layer 선언해서 추가하기
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape=(784,))
dense2 = keras.layers.Dense(10, activation='softmax')

model = keras.Sequential([dense1, dense2])

# %%
model.summary()

# 첫번쨰 차원은 샘플의 개수 -> 샘플개수가 아직 정의 X, None, why>? -> 훈련데이터를 조금씩 사용
#
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. sequential 객체에서 layer 만들기

model = keras.Sequential([
    keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden'),
    keras.layers.Dense(10, activation='softmax', input_shape=(784,), name='output')
], name='패션 MNIST 모델')

# print(model.summary())
# Out:
# Model: "패션 MNIST 모델"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# sequential 객체애 add 메서드로 추가해주기

model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.5679 - accuracy: 0.8069
# Epoch 2/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4125 - accuracy: 0.8511
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3786 - accuracy: 0.8636
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3558 - accuracy: 0.8712
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3386 - accuracy: 0.8770

# %%
print(train_scaled.shape)
# Out:
# (48000, 784)

# %%
# Relu 함수
# 렐루 함수는 max(0, z)와 같이 쓸 수 있습니다. 이 함수는 z가 0보다 크면 z를 출력하고 z가 0보다 작으면 0을 출력

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 784)               0
#
#  dense_12 (Dense)            (None, 100)               78500
#
#  dense_13 (Dense)            (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
(train_input, train_target), (test_input, test_target) =\
 keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(
 train_scaled, train_target, test_size=0.2, random_state=42)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.2661 - accuracy: 0.9026
# Epoch 2/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2621 - accuracy: 0.9059
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2554 - accuracy: 0.9093
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2522 - accuracy: 0.9104
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2494 - accuracy: 0.9120

# %%
sgd = keras.optimizers.SGD(learning_rate=0.1)
# model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics='accuracy') 에서 'sgd'랑 동일
